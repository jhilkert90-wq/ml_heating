# %% [markdown]
# InfluxDB Data Validation Notebook

# %% [markdown]
# Import necessary modules

# %%
import os
import sys
from datetime import datetime, timedelta, timezone
import pandas as pd
from dotenv import load_dotenv
import logging

# %% [markdown]
# Add parent directory to path to allow importing src modules

# %%
sys.path.insert(0, os.path.abspath('../src'))

import config
from ha_client import HAClient
from influx_service import InfluxService

# %% [markdown]
# Set up logging

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# Load environment variables from .env file

# %%
load_dotenv()

def get_influx_service() -> InfluxService:
    """Initializes and returns an InfluxService instance."""
    influx_url = os.getenv("INFLUX_URL")
    influx_token = os.getenv("INFLUX_TOKEN")
    influx_org = os.getenv("INFLUX_ORG")
    # InfluxService constructor does not take influx_bucket directly
    return InfluxService(influx_url, influx_token, influx_org)

def get_ha_client() -> HAClient:
    """Initializes and returns an HAClient instance."""
    hass_url = os.getenv("HASS_URL")
    hass_token = os.getenv("HASS_TOKEN")
    return HAClient(hass_url, hass_token)

# %% [markdown]
# Configuration Overview

# %% [markdown]
# Verify the key configuration settings for InfluxDB connection and the historical lookback window.

# %%
print(f"INFLUX_URL: {os.getenv('INFLUX_URL')}")
print(f"INFLUX_ORG: {os.getenv('INFLUX_ORG')}")
print(f"INFLUX_BUCKET: {os.getenv('INFLUX_BUCKET')}")
print(f"TRAINING_LOOKBACK_HOURS: {config.TRAINING_LOOKBACK_HOURS} hours")

influx_service = get_influx_service()
ha_client = get_ha_client()

end_time = datetime.now(timezone.utc)
start_time = end_time - timedelta(hours=config.TRAINING_LOOKBACK_HOURS)
num_steps = int((config.TRAINING_LOOKBACK_HOURS * 60) / config.HISTORY_STEP_MINUTES)

print(f"\nQuerying data from {start_time.isoformat()} to {end_time.isoformat()} for {num_steps} steps")
# Out:
# INFLUX_URL: http://20.10.0.10:8086
# INFLUX_ORG: erbehome
# INFLUX_BUCKET: home_assistant/autogen
# TRAINING_LOOKBACK_HOURS: 576 hours
#
# Querying data from 2025-11-07T09:49:41.690641+00:00 to 2025-12-01T09:49:41.690641+00:00 for 3456 steps

# %% [markdown]
# Entity IDs to Validate

# %% [markdown]
# These are the entity IDs that `src/physics_features.py` uses. We will check their historical data in InfluxDB.

# %%
entity_ids_to_check = [
    config.INDOOR_TEMP_ENTITY_ID,
    config.OUTDOOR_TEMP_ENTITY_ID,
    config.ACTUAL_OUTLET_TEMP_ENTITY_ID,
    config.TARGET_INDOOR_TEMP_ENTITY_ID,
    config.DHW_STATUS_ENTITY_ID,
    config.DISINFECTION_STATUS_ENTITY_ID,
    config.DHW_BOOST_HEATER_STATUS_ENTITY_ID,
    config.DEFROST_STATUS_ENTITY_ID,
    config.PV_POWER_ENTITY_ID,
    config.FIREPLACE_STATUS_ENTITY_ID,
    config.TV_STATUS_ENTITY_ID,
    config.PV_FORECAST_ENTITY_ID
]

print("Entities that will be validated:")
for eid in entity_ids_to_check:
    print(f"- {eid}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       1 entity_ids_to_check = [
#       2     config.INDOOR_TEMP_ENTITY_ID,
#       3     config.OUTDOOR_TEMP_ENTITY_ID,
#       4     config.ACTUAL_OUTLET_TEMP_ENTITY_ID,
#       5     config.TARGET_INDOOR_TEMP_ENTITY_ID,
#       6     config.DHW_STATUS_ENTITY_ID,
#       7     config.DISINFECTION_STATUS_ENTITY_ID,
#       8     config.DHW_BOOST_HEATER_STATUS_ENTITY_ID,
#       9     config.DEFROST_STATUS_ENTITY_ID,
# ---> 10     config.PV1_POWER_ENTITY_ID,
#      11     config.PV2_POWER_ENTITY_ID,
#      12     config.PV3_POWER_ENTITY_ID,
#      13     config.FIREPLACE_STATUS_ENTITY_ID,
#      14     config.TV_STATUS_ENTITY_ID,
#      15     config.PV_FORECAST_ENTITY_ID
#      16 ]
#      18 print("Entities that will be validated:")
#      19 for eid in entity_ids_to_check:
#
# AttributeError: module 'config' has no attribute 'PV1_POWER_ENTITY_ID'

# %% [markdown]
# InfluxDB Data Retrieval and Summary

# %% [markdown]
# This section queries InfluxDB for each specified entity and provides a summary of the retrieved data, including count, time range, and a data preview. For binary sensors, it will also show 'on' events and duration.

# %%
async def validate_entity_data(entity_id: str):
    print(f"\n--- Validating {entity_id} ---")

    # Special handling for PV forecast as it's an attribute, not a simple state
    if entity_id == config.PV_FORECAST_ENTITY_ID:
        print("PV Forecast (attributes) cannot be directly queried from InfluxDB by entity_id alone.")
        print("Its data is usually part of a specific sensor's state attributes in HA.")
        print("Please check the live HA state for this entity in the previous notebook if needed.")
        return

    is_binary_sensor = entity_id in [config.DHW_STATUS_ENTITY_ID, config.DISINFECTION_STATUS_ENTITY_ID, config.DHW_BOOST_HEATER_STATUS_ENTITY_ID, config.DEFROST_STATUS_ENTITY_ID, config.FIREPLACE_STATUS_ENTITY_ID, config.TV_STATUS_ENTITY_ID]

    agg_fn = "max" if is_binary_sensor else "mean"
    default_val = 0.0 if is_binary_sensor else 20.0 # Default for temps, 0 for binary

    try:
        # Use fetch_history with appropriate parameters
        history_values = influx_service.fetch_history(entity_id, num_steps, default_val, agg_fn=agg_fn)

        if not history_values:
            print(f"No data found for {entity_id} in the last {config.TRAINING_LOOKBACK_HOURS} hours.")
            return

        # Create a DataFrame for consistent processing
        # Approximate timestamps for the fetched values
        times = [end_time - timedelta(minutes=i * config.HISTORY_STEP_MINUTES) for i in range(num_steps)][::-1]
        df = pd.DataFrame({'time': times, 'value': history_values})
        df['time'] = pd.to_datetime(df['time'])

        print(f"Total records found: {len(df)}")
        print(f"Time range: {df['time'].min()} to {df['time'].max()}")
        print("Data preview (first 5 rows):")
        print(df.head())
        print("\nData preview (last 5 rows):")
        print(df.tail())

        # Add min, max, and average value
        if not df.empty:
            print(f"Min value: {df['value'].min()}")
            print(f"Max value: {df['value'].max()}")
            print(f"Average value: {df['value'].mean()}")

        if is_binary_sensor:
            # Filter for 'on' states (assuming 1 for on, 0 for off)
            on_states = df[df['value'] > 0]

            if not on_states.empty:
                print(f"Binary sensor was 'ON' for {len(on_states)} of {num_steps} periods.")
                # Calculate total duration it was 'on'
                total_on_duration_seconds = len(on_states) * config.HISTORY_STEP_MINUTES * 60
                print(f"Approximate total 'ON' duration: {timedelta(seconds=total_on_duration_seconds)}")
            else:
                print("Binary sensor was never 'ON' in the queried period.")

    except Exception as e:
        print(f"Error fetching data for {entity_id}: {e}")


import asyncio

async def main():
    for entity_id in entity_ids_to_check:
        await validate_entity_data(entity_id)

await main()
# Out:
# --- Validating sensor.thermometer_wohnzimmer_kompensiert ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00   21.7
# 1 2025-11-03 09:02:12.766711+00:00   21.8
# 2 2025-11-03 09:12:12.766711+00:00   21.6
# 3 2025-11-03 09:22:12.766711+00:00   21.6
# 4 2025-11-03 09:32:12.766711+00:00   21.6
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00   20.8
# 3452 2025-11-27 08:12:12.766711+00:00   20.8
# 3453 2025-11-27 08:22:12.766711+00:00   20.8
# 3454 2025-11-27 08:32:12.766711+00:00   20.8
# 3455 2025-11-27 08:42:12.766711+00:00   20.8
# Min value: 17.8
# Max value: 22.099999999999998
# Average value: 20.798148148148154
#
# --- Validating sensor.thermometer_waermepume_kompensiert ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00   11.6
# 1 2025-11-03 09:02:12.766711+00:00   11.8
# 2 2025-11-03 09:12:12.766711+00:00   12.0
# 3 2025-11-03 09:22:12.766711+00:00   11.8
# 4 2025-11-03 09:32:12.766711+00:00   12.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    1.2
# 3452 2025-11-27 08:12:12.766711+00:00    1.2
# 3453 2025-11-27 08:22:12.766711+00:00    1.2
# 3454 2025-11-27 08:32:12.766711+00:00    1.2
# 3455 2025-11-27 08:42:12.766711+00:00    1.2
# Min value: -7.0
# Max value: 15.6
# Average value: 3.1667245370370374
#
# --- Validating sensor.hp_outlet_temp ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00  38.00
# 1 2025-11-03 09:02:12.766711+00:00  38.30
# 2 2025-11-03 09:12:12.766711+00:00  37.85
# 3 2025-11-03 09:22:12.766711+00:00  37.85
# 4 2025-11-03 09:32:12.766711+00:00  37.76
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00  45.85
# 3452 2025-11-27 08:12:12.766711+00:00  45.85
# 3453 2025-11-27 08:22:12.766711+00:00  45.85
# 3454 2025-11-27 08:32:12.766711+00:00  45.85
# 3455 2025-11-27 08:42:12.766711+00:00  45.85
# Min value: 21.03333333333333
# Max value: 62.7
# Average value: 40.66857101047423
#
# --- Validating input_number.hp_auto_correct_target ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00   21.0
# 1 2025-11-03 09:02:12.766711+00:00   21.5
# 2 2025-11-03 09:12:12.766711+00:00   16.5
# 3 2025-11-03 09:22:12.766711+00:00   18.0
# 4 2025-11-03 09:32:12.766711+00:00   17.5
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00   21.0
# 3452 2025-11-27 08:12:12.766711+00:00   21.0
# 3453 2025-11-27 08:22:12.766711+00:00   21.0
# 3454 2025-11-27 08:32:12.766711+00:00   21.0
# 3455 2025-11-27 08:42:12.766711+00:00   21.0
# Min value: 16.5
# Max value: 22.0
# Average value: 20.995167824074073
#
# --- Validating binary_sensor.hp_dhw_heating_status ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00    0.0
# 1 2025-11-03 09:02:12.766711+00:00    0.0
# 2 2025-11-03 09:12:12.766711+00:00    1.0
# 3 2025-11-03 09:22:12.766711+00:00    0.0
# 4 2025-11-03 09:32:12.766711+00:00    0.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    0.0
# 3452 2025-11-27 08:12:12.766711+00:00    0.0
# 3453 2025-11-27 08:22:12.766711+00:00    0.0
# 3454 2025-11-27 08:32:12.766711+00:00    0.0
# 3455 2025-11-27 08:42:12.766711+00:00    0.0
# Min value: 0.0
# Max value: 1.0
# Average value: 0.01244212962962963
# Binary sensor was 'ON' for 43 of 3456 periods.
# Approximate total 'ON' duration: 7:10:00
#
# --- Validating binary_sensor.hp_dhw_tank_disinfection_status ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00    0.0
# 1 2025-11-03 09:02:12.766711+00:00    0.0
# 2 2025-11-03 09:12:12.766711+00:00    0.0
# 3 2025-11-03 09:22:12.766711+00:00    0.0
# 4 2025-11-03 09:32:12.766711+00:00    0.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    0.0
# 3452 2025-11-27 08:12:12.766711+00:00    0.0
# 3453 2025-11-27 08:22:12.766711+00:00    0.0
# 3454 2025-11-27 08:32:12.766711+00:00    0.0
# 3455 2025-11-27 08:42:12.766711+00:00    0.0
# Min value: 0.0
# Max value: 1.0
# Average value: 0.00028935185185185184
# Binary sensor was 'ON' for 1 of 3456 periods.
# Approximate total 'ON' duration: 0:10:00
#
# --- Validating binary_sensor.hp_dhw_boost_heater_status ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00    0.0
# 1 2025-11-03 09:02:12.766711+00:00    0.0
# 2 2025-11-03 09:12:12.766711+00:00    0.0
# 3 2025-11-03 09:22:12.766711+00:00    0.0
# 4 2025-11-03 09:32:12.766711+00:00    0.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    0.0
# 3452 2025-11-27 08:12:12.766711+00:00    0.0
# 3453 2025-11-27 08:22:12.766711+00:00    0.0
# 3454 2025-11-27 08:32:12.766711+00:00    0.0
# 3455 2025-11-27 08:42:12.766711+00:00    0.0
# Min value: 0.0
# Max value: 1.0
# Average value: 0.00028935185185185184
# Binary sensor was 'ON' for 1 of 3456 periods.
# Approximate total 'ON' duration: 0:10:00
#
# --- Validating binary_sensor.hp_defrosting_status ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00    0.0
# 1 2025-11-03 09:02:12.766711+00:00    0.0
# 2 2025-11-03 09:12:12.766711+00:00    0.0
# 3 2025-11-03 09:22:12.766711+00:00    0.0
# 4 2025-11-03 09:32:12.766711+00:00    0.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    1.0
# 3452 2025-11-27 08:12:12.766711+00:00    1.0
# 3453 2025-11-27 08:22:12.766711+00:00    1.0
# 3454 2025-11-27 08:32:12.766711+00:00    1.0
# 3455 2025-11-27 08:42:12.766711+00:00    1.0
# Min value: 0.0
# Max value: 1.0
# Average value: 0.9421296296296297
# Binary sensor was 'ON' for 3256 of 3456 periods.
# Approximate total 'ON' duration: 22 days, 14:40:00
#
# --- Validating sensor.saj_pv1_power ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time       value
# 0 2025-11-03 08:52:12.766711+00:00  396.142857
# 1 2025-11-03 09:02:12.766711+00:00  393.125000
# 2 2025-11-03 09:12:12.766711+00:00  429.333333
# 3 2025-11-03 09:22:12.766711+00:00  511.125000
# 4 2025-11-03 09:32:12.766711+00:00  718.555556
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00  114.0
# 3452 2025-11-27 08:12:12.766711+00:00  114.0
# 3453 2025-11-27 08:22:12.766711+00:00  114.0
# 3454 2025-11-27 08:32:12.766711+00:00  114.0
# 3455 2025-11-27 08:42:12.766711+00:00  114.0
# Min value: 0.0
# Max value: 1353.75
# Average value: 106.96648616622576
#
# --- Validating sensor.saj_pv2_power ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time       value
# 0 2025-11-03 08:52:12.766711+00:00  321.142857
# 1 2025-11-03 09:02:12.766711+00:00  325.875000
# 2 2025-11-03 09:12:12.766711+00:00  376.888889
# 3 2025-11-03 09:22:12.766711+00:00  462.375000
# 4 2025-11-03 09:32:12.766711+00:00  707.777778
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00  142.5
# 3452 2025-11-27 08:12:12.766711+00:00  142.5
# 3453 2025-11-27 08:22:12.766711+00:00  142.5
# 3454 2025-11-27 08:32:12.766711+00:00  142.5
# 3455 2025-11-27 08:42:12.766711+00:00  142.5
# Min value: 0.0
# Max value: 1341.75
# Average value: 94.81838704714139
#
# --- Validating sensor.solarmax_pv_power ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time       value
# 0 2025-11-03 08:52:12.766711+00:00  385.161290
# 1 2025-11-03 09:02:12.766711+00:00  400.947368
# 2 2025-11-03 09:12:12.766711+00:00  448.549550
# 3 2025-11-03 09:22:12.766711+00:00  524.094017
# 4 2025-11-03 09:32:12.766711+00:00  633.258333
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00  346.0
# 3452 2025-11-27 08:12:12.766711+00:00  346.0
# 3453 2025-11-27 08:22:12.766711+00:00  346.0
# 3454 2025-11-27 08:32:12.766711+00:00  346.0
# 3455 2025-11-27 08:42:12.766711+00:00  346.0
# Min value: 0.0
# Max value: 1096.906976744186
# Average value: 311.8134056486276
#
# --- Validating binary_sensor.fireplace_active ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00    0.0
# 1 2025-11-03 09:02:12.766711+00:00    0.0
# 2 2025-11-03 09:12:12.766711+00:00    0.0
# 3 2025-11-03 09:22:12.766711+00:00    0.0
# 4 2025-11-03 09:32:12.766711+00:00    0.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    0.0
# 3452 2025-11-27 08:12:12.766711+00:00    0.0
# 3453 2025-11-27 08:22:12.766711+00:00    0.0
# 3454 2025-11-27 08:32:12.766711+00:00    0.0
# 3455 2025-11-27 08:42:12.766711+00:00    0.0
# Min value: 0.0
# Max value: 1.0
# Average value: 0.0005787037037037037
# Binary sensor was 'ON' for 2 of 3456 periods.
# Approximate total 'ON' duration: 0:20:00
#
# --- Validating input_boolean.fernseher ---
# Total records found: 3456
# Time range: 2025-11-03 08:52:12.766711+00:00 to 2025-11-27 08:42:12.766711+00:00
# Data preview (first 5 rows):
#                               time  value
# 0 2025-11-03 08:52:12.766711+00:00    1.0
# 1 2025-11-03 09:02:12.766711+00:00    0.0
# 2 2025-11-03 09:12:12.766711+00:00    1.0
# 3 2025-11-03 09:22:12.766711+00:00    0.0
# 4 2025-11-03 09:32:12.766711+00:00    1.0
#
# Data preview (last 5 rows):
#                                  time  value
# 3451 2025-11-27 08:02:12.766711+00:00    0.0
# 3452 2025-11-27 08:12:12.766711+00:00    0.0
# 3453 2025-11-27 08:22:12.766711+00:00    0.0
# 3454 2025-11-27 08:32:12.766711+00:00    0.0
# 3455 2025-11-27 08:42:12.766711+00:00    0.0
# Min value: 0.0
# Max value: 1.0
# Average value: 0.013599537037037037
# Binary sensor was 'ON' for 47 of 3456 periods.
# Approximate total 'ON' duration: 7:50:00
#
# --- Validating sensor.energy_production_today_4 ---
# PV Forecast (attributes) cannot be directly queried from InfluxDB by entity_id alone.
# Its data is usually part of a specific sensor's state attributes in HA.
# Please check the live HA state for this entity in the previous notebook if needed.

# %% [markdown]
# Next Steps

# %% [markdown]
# Based on the output above, you can now:
# 1.  **Verify Entity IDs**: Ensure that the entity IDs specified in your `.env` and `config.py` accurately reflect the sensors logging data to InfluxDB.

# %% [markdown]
# 2.  **Check Data Presence**: Confirm that data exists for critical entities, especially for `pv_now`, `fireplace_on`, and `tv_on` if they are being used.

# %% [markdown]
# 3.  **Inspect Values**: Look at the data previews to ensure the values are reasonable and not static or erroneous.

# %% [markdown]
# 4.  **Adjust `TRAINING_LOOKBACK_HOURS`**: If data is sparse, consider if `TRAINING_LOOKBACK_HOURS` is too short.

# %% [markdown]
# 5.  **Review Home Assistant to InfluxDB Integration**: If data is missing or incorrect, investigate your Home Assistant configuration for sending data to InfluxDB.
